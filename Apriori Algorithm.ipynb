# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('C:\\Users\\tomee\\Downloads\\datasets\\groceries_dataset.csv')

# %%
df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
grocery_df_date= df.groupby('Date').agg({'itemDescription':','.join})

# %%
grocery_df_date
# Out:
#                                               itemDescription
# Date
# 01-01-2014  cleaner,sausage,tropical fruit,whole milk,citr...
# 01-01-2015  canned beer,frozen meals,butter,ham,citrus fru...
# 01-02-2014  other vegetables,pip fruit,frankfurter,sugar,o...
# 01-02-2015  whole milk,canned beer,bottled water,soda,whol...
# 01-03-2014  sausage,meat,sugar,sausage,bottled beer,whole ...
# ...                                                       ...
# 31-07-2015  vinegar,chicken,root vegetables,chicken,sausag...
# 31-08-2014  pork,other vegetables,beef,whole milk,hygiene ...
# 31-08-2015  brown bread,frankfurter,chicken,citrus fruit,b...
# 31-10-2014  yogurt,frankfurter,other vegetables,salty snac...
# 31-10-2015  chicken,canned beer,frozen vegetables,beef,can...
#
# [728 rows x 1 columns]

# %%
grocery_df_date.head()
# Out:
#                                               itemDescription
# Date
# 01-01-2014  cleaner,sausage,tropical fruit,whole milk,citr...
# 01-01-2015  canned beer,frozen meals,butter,ham,citrus fru...
# 01-02-2014  other vegetables,pip fruit,frankfurter,sugar,o...
# 01-02-2015  whole milk,canned beer,bottled water,soda,whol...
# 01-03-2014  sausage,meat,sugar,sausage,bottled beer,whole ...

# %%
#associative rule according to gouping by items sold on date

# %%
grocery_df_date['itemDescription'] = grocery_df_date['itemDescription'].str.split(',')

# %%
transactions=[]
for i in range(0,len(grocery_df_date)):
    transactions.append(grocery_df_date['itemDescription'][i])

# %%
from apyori import apriori
rules = apriori(transactions=transactions,min_support=0.005,min_confidence=0.7,min_lift=3,
                min_length=3,max_length=3)

# %%
#visualizing results

# %%
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'oil', 'salad dressing'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing'}), items_add=frozenset({'oil'}), confidence=0.8333333333333333, lift=3.1111111111111107)]),
#  RelationRecord(items=frozenset({'semi-finished bread', 'Instant food products', 'female sanitary products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Instant food products', 'female sanitary products'}), items_add=frozenset({'semi-finished bread'}), confidence=0.8, lift=4.585826771653544)]),
#  RelationRecord(items=frozenset({'mustard', 'salt', 'Instant food products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mustard', 'Instant food products'}), items_add=frozenset({'salt'}), confidence=0.8, lift=7.372151898734177)]),
#  RelationRecord(items=frozenset({'spread cheese', 'Instant food products', 'pickled vegetables'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spread cheese', 'Instant food products'}), items_add=frozenset({'pickled vegetables'}), confidence=0.8, lift=4.813223140495868)]),
#  RelationRecord(items=frozenset({'spread cheese', 'Instant food products', 'sliced cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spread cheese', 'Instant food products'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'abrasive cleaner', 'UHT-milk', 'chewing gum'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'abrasive cleaner', 'UHT-milk'}), items_add=frozenset({'chewing gum'}), confidence=0.8, lift=3.5730061349693254)]),
#  RelationRecord(items=frozenset({'UHT-milk', 'ready soups', 'candy'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'UHT-milk', 'ready soups'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'UHT-milk', 'skin care', 'candy'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'UHT-milk', 'skin care'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'chewing gum', 'UHT-milk', 'snack products'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'UHT-milk', 'snack products'}), items_add=frozenset({'chewing gum'}), confidence=0.7142857142857142, lift=3.190184049079754)]),
#  RelationRecord(items=frozenset({'flower soil/fertilizer', 'UHT-milk', 'pasta'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flower soil/fertilizer', 'UHT-milk'}), items_add=frozenset({'pasta'}), confidence=0.8, lift=5.153982300884956)]),
#  RelationRecord(items=frozenset({'sugar', 'UHT-milk', 'frozen fruits'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'UHT-milk', 'frozen fruits'}), items_add=frozenset({'sugar'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'organic products', 'UHT-milk', 'hard cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'organic products', 'UHT-milk'}), items_add=frozenset({'hard cheese'}), confidence=0.8, lift=3.1481081081081084)]),
#  RelationRecord(items=frozenset({'prosecco', 'UHT-milk', 'hygiene articles'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'UHT-milk', 'prosecco'}), items_add=frozenset({'hygiene articles'}), confidence=0.8571428571428571, lift=3.4475138121546958)]),
#  RelationRecord(items=frozenset({'meat spreads', 'UHT-milk', 'long life bakery product'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meat spreads', 'UHT-milk'}), items_add=frozenset({'long life bakery product'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'UHT-milk', 'syrup', 'processed cheese'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'UHT-milk', 'syrup'}), items_add=frozenset({'processed cheese'}), confidence=0.7142857142857142, lift=3.741007194244604)]),
#  RelationRecord(items=frozenset({'UHT-milk', 'sliced cheese', 'pudding powder'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'UHT-milk', 'pudding powder'}), items_add=frozenset({'sliced cheese'}), confidence=0.8333333333333333, lift=3.261648745519713)]),
#  RelationRecord(items=frozenset({'baking powder', 'abrasive cleaner', 'oil'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'baking powder', 'abrasive cleaner'}), items_add=frozenset({'oil'}), confidence=1.0, lift=3.7333333333333334), OrderedStatistic(items_base=frozenset({'abrasive cleaner', 'oil'}), items_add=frozenset({'baking powder'}), confidence=0.7142857142857142, lift=4.727272727272727)]),
#  RelationRecord(items=frozenset({'beverages', 'chewing gum', 'abrasive cleaner'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages', 'abrasive cleaner'}), items_add=frozenset({'chewing gum'}), confidence=0.7142857142857142, lift=3.190184049079754)]),
#  RelationRecord(items=frozenset({'ham', 'abrasive cleaner', 'candy'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham', 'abrasive cleaner'}), items_add=frozenset({'candy'}), confidence=0.8333333333333333, lift=3.1433506044905006)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'flour', 'abrasive cleaner'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flour', 'abrasive cleaner'}), items_add=frozenset({'specialty chocolate'}), confidence=0.8333333333333333, lift=3.0485762144053603)]),
#  RelationRecord(items=frozenset({'red/blush wine', 'cat food', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'red/blush wine', 'artif. sweetener'}), items_add=frozenset({'cat food'}), confidence=0.8, lift=3.75741935483871)]),
#  RelationRecord(items=frozenset({'chewing gum', 'fruit/vegetable juice', 'artif. sweetener'}), support=0.009615384615384616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fruit/vegetable juice', 'artif. sweetener'}), items_add=frozenset({'chewing gum'}), confidence=0.7000000000000001, lift=3.1263803680981597)]),
#  RelationRecord(items=frozenset({'chewing gum', 'pickled vegetables', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pickled vegetables', 'artif. sweetener'}), items_add=frozenset({'chewing gum'}), confidence=0.8, lift=3.5730061349693254)]),
#  RelationRecord(items=frozenset({'specialty bar', 'coffee', 'artif. sweetener'}), support=0.01098901098901099, ordered_statistics=[OrderedStatistic(items_base=frozenset({'coffee', 'artif. sweetener'}), items_add=frozenset({'specialty bar'}), confidence=0.8, lift=3.165217391304348)]),
#  RelationRecord(items=frozenset({'herbs', 'dishes', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'dishes', 'artif. sweetener'}), items_add=frozenset({'herbs'}), confidence=0.8, lift=4.189928057553957)]),
#  RelationRecord(items=frozenset({'ice cream', 'specialty bar', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ice cream', 'artif. sweetener'}), items_add=frozenset({'specialty bar'}), confidence=0.8, lift=3.165217391304348)]),
#  RelationRecord(items=frozenset({'ice cream', 'white wine', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ice cream', 'artif. sweetener'}), items_add=frozenset({'white wine'}), confidence=0.8, lift=3.7095541401273886)]),
#  RelationRecord(items=frozenset({'meat', 'sparkling wine', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sparkling wine', 'artif. sweetener'}), items_add=frozenset({'meat'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'spread cheese', 'pickled vegetables', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pickled vegetables', 'artif. sweetener'}), items_add=frozenset({'spread cheese'}), confidence=0.8, lift=6.130526315789473)]),
#  RelationRecord(items=frozenset({'white wine', 'sparkling wine', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sparkling wine', 'artif. sweetener'}), items_add=frozenset({'white wine'}), confidence=1.0, lift=4.6369426751592355)]),
#  RelationRecord(items=frozenset({'margarine', 'bags', 'butter'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bags'}), items_add=frozenset({'margarine', 'butter'}), confidence=1.0, lift=4.136363636363637)]),
#  RelationRecord(items=frozenset({'margarine', 'bags', 'pip fruit'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bags'}), items_add=frozenset({'margarine', 'pip fruit'}), confidence=1.0, lift=3.294117647058824)]),
#  RelationRecord(items=frozenset({'baking powder', 'decalcifier', 'brown bread'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'decalcifier', 'brown bread'}), items_add=frozenset({'baking powder'}), confidence=0.8, lift=5.294545454545455)]),
#  RelationRecord(items=frozenset({'baking powder', 'butter milk', 'curd cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'baking powder', 'curd cheese'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'canned beer', 'baking powder', 'decalcifier'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned beer', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.8, lift=5.294545454545455)]),
#  RelationRecord(items=frozenset({'baking powder', 'chocolate', 'decalcifier'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=1.0, lift=6.618181818181818)]),
#  RelationRecord(items=frozenset({'light bulbs', 'baking powder', 'cling film/bags'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light bulbs', 'baking powder'}), items_add=frozenset({'cling film/bags'}), confidence=0.8, lift=8.32)]),
#  RelationRecord(items=frozenset({'curd', 'baking powder', 'decalcifier'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=1.0, lift=6.618181818181818)]),
#  RelationRecord(items=frozenset({'baking powder', 'domestic eggs', 'decalcifier'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'domestic eggs', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.8, lift=5.294545454545455)]),
#  RelationRecord(items=frozenset({'baking powder', 'decalcifier', 'hard cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'decalcifier', 'hard cheese'}), items_add=frozenset({'baking powder'}), confidence=0.8, lift=5.294545454545455)]),
#  RelationRecord(items=frozenset({'baking powder', 'herbs', 'decalcifier'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herbs', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=1.0, lift=6.618181818181818)]),
#  RelationRecord(items=frozenset({'baking powder', 'newspapers', 'decalcifier'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'newspapers', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.75, lift=4.963636363636364)]),
#  RelationRecord(items=frozenset({'baking powder', 'pastry', 'decalcifier'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pastry', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.8333333333333333, lift=5.515151515151515)]),
#  RelationRecord(items=frozenset({'root vegetables', 'baking powder', 'decalcifier'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.7142857142857142, lift=4.727272727272727)]),
#  RelationRecord(items=frozenset({'tropical fruit', 'baking powder', 'decalcifier'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tropical fruit', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.8333333333333333, lift=5.515151515151515)]),
#  RelationRecord(items=frozenset({'yogurt', 'baking powder', 'decalcifier'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.7142857142857142, lift=4.727272727272727)]),
#  RelationRecord(items=frozenset({'baking powder', 'specialty bar', 'fish'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'baking powder', 'fish'}), items_add=frozenset({'specialty bar'}), confidence=1.0, lift=3.956521739130435)]),
#  RelationRecord(items=frozenset({'ice cream', 'baking powder', 'turkey'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'baking powder', 'turkey'}), items_add=frozenset({'ice cream'}), confidence=0.8571428571428571, lift=3.0144927536231885)]),
#  RelationRecord(items=frozenset({'baking powder', 'pet care', 'semi-finished bread'}), support=0.009615384615384616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'baking powder', 'pet care'}), items_add=frozenset({'semi-finished bread'}), confidence=0.7000000000000001, lift=4.012598425196851)]),
#  RelationRecord(items=frozenset({'baking powder', 'specialty bar', 'potato products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'baking powder', 'potato products'}), items_add=frozenset({'specialty bar'}), confidence=0.8, lift=3.165217391304348)]),
#  RelationRecord(items=frozenset({'bathroom cleaner', 'sliced cheese', 'candy'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bathroom cleaner', 'sliced cheese'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'bathroom cleaner', 'grapes', 'condensed milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bathroom cleaner', 'condensed milk'}), items_add=frozenset({'grapes'}), confidence=1.0, lift=4.089887640449438), OrderedStatistic(items_base=frozenset({'bathroom cleaner', 'grapes'}), items_add=frozenset({'condensed milk'}), confidence=0.8, lift=6.471111111111111)]),
#  RelationRecord(items=frozenset({'bathroom cleaner', 'waffles', 'condensed milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bathroom cleaner', 'condensed milk'}), items_add=frozenset({'waffles'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'oil', 'salad dressing', 'berries'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing', 'berries'}), items_add=frozenset({'oil'}), confidence=1.0, lift=3.7333333333333334)]),
#  RelationRecord(items=frozenset({'beverages', 'snack products', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages', 'snack products'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'beverages', 'ham', 'snack products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages', 'snack products'}), items_add=frozenset({'ham'}), confidence=1.0, lift=3.4018691588785046)]),
#  RelationRecord(items=frozenset({'beverages', 'whisky', 'long life bakery product'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whisky', 'long life bakery product'}), items_add=frozenset({'beverages'}), confidence=1.0, lift=3.4178403755868545)]),
#  RelationRecord(items=frozenset({'beverages', 'soft cheese', 'nut snack'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'nut snack', 'soft cheese'}), items_add=frozenset({'beverages'}), confidence=1.0, lift=3.4178403755868545)]),
#  RelationRecord(items=frozenset({'beverages', 'processed cheese', 'syrup'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages', 'syrup'}), items_add=frozenset({'processed cheese'}), confidence=0.8, lift=4.189928057553957)]),
#  RelationRecord(items=frozenset({'beverages', 'specialty bar', 'rum'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages', 'rum'}), items_add=frozenset({'specialty bar'}), confidence=0.8, lift=3.165217391304348)]),
#  RelationRecord(items=frozenset({'beverages', 'rum', 'waffles'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages', 'rum'}), items_add=frozenset({'waffles'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'beverages', 'salty snack', 'tea'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages', 'tea'}), items_add=frozenset({'salty snack'}), confidence=1.0, lift=3.1790393013100435)]),
#  RelationRecord(items=frozenset({'make up remover', 'chocolate', 'bottled beer'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'make up remover'}), items_add=frozenset({'chocolate', 'bottled beer'}), confidence=0.8, lift=3.64)]),
#  RelationRecord(items=frozenset({'make up remover', 'margarine', 'bottled beer'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'make up remover'}), items_add=frozenset({'margarine', 'bottled beer'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'brandy', 'white wine', 'cake bar'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brandy', 'white wine'}), items_add=frozenset({'cake bar'}), confidence=0.7142857142857142, lift=5.909090909090908)]),
#  RelationRecord(items=frozenset({'brandy', 'ham', 'pot plants'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brandy', 'pot plants'}), items_add=frozenset({'ham'}), confidence=1.0, lift=3.4018691588785046)]),
#  RelationRecord(items=frozenset({'brandy', 'popcorn', 'long life bakery product'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brandy', 'popcorn'}), items_add=frozenset({'long life bakery product'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'brandy', 'specialty chocolate', 'processed cheese'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brandy', 'processed cheese'}), items_add=frozenset({'specialty chocolate'}), confidence=0.8333333333333333, lift=3.0485762144053603)]),
#  RelationRecord(items=frozenset({'chewing gum', 'cookware', 'brown bread'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cookware', 'brown bread'}), items_add=frozenset({'chewing gum'}), confidence=0.75, lift=3.349693251533742)]),
#  RelationRecord(items=frozenset({'misc. beverages', 'flower soil/fertilizer', 'butter'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flower soil/fertilizer', 'butter'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797)]),
#  RelationRecord(items=frozenset({'misc. beverages', 'salad dressing', 'butter'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing', 'butter'}), items_add=frozenset({'misc. beverages'}), confidence=1.0, lift=3.8930481283422465)]),
#  RelationRecord(items=frozenset({'rice', 'canned vegetables', 'butter milk'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rice', 'canned vegetables'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'softener', 'canned vegetables', 'butter milk'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'softener', 'canned vegetables'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'cat food', 'butter milk', 'dental care'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'dental care', 'cat food'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'male cosmetics', 'cat food', 'butter milk'}), support=0.009615384615384616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'male cosmetics', 'butter milk'}), items_add=frozenset({'cat food'}), confidence=0.7777777777777779, lift=3.6530465949820794)]),
#  RelationRecord(items=frozenset({'cereals', 'butter milk', 'frozen dessert'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'frozen dessert'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'organic products', 'chicken', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'organic products', 'chicken'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'chocolate marshmallow', 'butter milk', 'flower (seeds)'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate marshmallow', 'flower (seeds)'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'decalcifier', 'butter milk', 'hard cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'decalcifier', 'butter milk'}), items_add=frozenset({'hard cheese'}), confidence=0.8, lift=3.1481081081081084)]),
#  RelationRecord(items=frozenset({'decalcifier', 'butter milk', 'sausage'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'decalcifier', 'sausage'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'domestic eggs', 'toilet cleaner', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'toilet cleaner'}), items_add=frozenset({'domestic eggs', 'butter milk'}), confidence=0.8, lift=4.6967741935483875), OrderedStatistic(items_base=frozenset({'domestic eggs', 'toilet cleaner'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'finished products', 'vinegar', 'butter milk'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'finished products', 'vinegar'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'sparkling wine', 'butter milk', 'flower (seeds)'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sparkling wine', 'flower (seeds)'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'rice', 'butter milk', 'frozen dessert'}), support=0.01098901098901099, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rice', 'frozen dessert'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'snack products', 'grapes', 'butter milk'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'grapes', 'snack products'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'hair spray', 'hygiene articles', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hair spray', 'butter milk'}), items_add=frozenset({'hygiene articles'}), confidence=0.8, lift=3.2176795580110498), OrderedStatistic(items_base=frozenset({'hair spray', 'hygiene articles'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'potato products', 'butter milk', 'hamburger meat'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'potato products', 'hamburger meat'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'honey', 'sliced cheese', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sliced cheese', 'honey'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'kitchen towels', 'processed cheese', 'butter milk'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'kitchen towels', 'butter milk'}), items_add=frozenset({'processed cheese'}), confidence=0.7142857142857142, lift=3.741007194244604)]),
#  RelationRecord(items=frozenset({'organic sausage', 'butter milk', 'liquor'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'organic sausage', 'liquor'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'napkins', 'toilet cleaner', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'toilet cleaner'}), items_add=frozenset({'napkins', 'butter milk'}), confidence=0.8, lift=6.195744680851064), OrderedStatistic(items_base=frozenset({'napkins', 'toilet cleaner'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'processed cheese', 'syrup', 'butter milk'}), support=0.009615384615384616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'syrup', 'butter milk'}), items_add=frozenset({'processed cheese'}), confidence=0.7777777777777779, lift=4.073541167066348)]),
#  RelationRecord(items=frozenset({'soda', 'toilet cleaner', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda', 'toilet cleaner'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'cake bar', 'soups', 'candy'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake bar', 'soups'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'canned vegetables', 'cake bar', 'hygiene articles'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned vegetables', 'cake bar'}), items_add=frozenset({'hygiene articles'}), confidence=0.8571428571428571, lift=3.4475138121546958)]),
#  RelationRecord(items=frozenset({'cereals', 'cake bar', 'pickled vegetables'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'cake bar'}), items_add=frozenset({'pickled vegetables'}), confidence=0.8, lift=4.813223140495868)]),
#  RelationRecord(items=frozenset({'detergent', 'cake bar', 'soups'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake bar', 'soups'}), items_add=frozenset({'detergent'}), confidence=0.8, lift=4.894117647058824)]),
#  RelationRecord(items=frozenset({'finished products', 'frozen potato products', 'cake bar'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'finished products', 'cake bar'}), items_add=frozenset({'frozen potato products'}), confidence=0.8, lift=8.692537313432835)]),
#  RelationRecord(items=frozenset({'flour', 'softener', 'cake bar'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'softener', 'cake bar'}), items_add=frozenset({'flour'}), confidence=0.8, lift=4.314074074074074)]),
#  RelationRecord(items=frozenset({'jam', 'sugar', 'cake bar'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'jam', 'cake bar'}), items_add=frozenset({'sugar'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'candles', 'cling film/bags'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'candles', 'cling film/bags'}), items_add=frozenset({'specialty chocolate'}), confidence=1.0, lift=3.6582914572864325)]),
#  RelationRecord(items=frozenset({'candles', 'oil', 'condensed milk'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'candles', 'condensed milk'}), items_add=frozenset({'oil'}), confidence=0.8333333333333333, lift=3.1111111111111107)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'frozen potato products', 'candles'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen potato products', 'candles'}), items_add=frozenset({'specialty chocolate'}), confidence=0.8333333333333333, lift=3.0485762144053603)]),
#  RelationRecord(items=frozenset({'zwieback', 'meat', 'candles'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'zwieback', 'candles'}), items_add=frozenset({'meat'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'candles', 'pet care'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'candles', 'pet care'}), items_add=frozenset({'specialty chocolate'}), confidence=1.0, lift=3.6582914572864325)]),
#  RelationRecord(items=frozenset({'candles', 'sparkling wine', 'specialty cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'candles', 'sparkling wine'}), items_add=frozenset({'specialty cheese'}), confidence=0.8, lift=8.32)]),
#  RelationRecord(items=frozenset({'cat food', 'potato products', 'candy'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'potato products', 'cat food'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'rum', 'candy', 'condensed milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rum', 'condensed milk'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'flour', 'rum', 'candy'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flour', 'rum'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'ketchup', 'candy', 'house keeping products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ketchup', 'house keeping products'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'prosecco', 'hygiene articles', 'candy'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'prosecco', 'candy'}), items_add=frozenset({'hygiene articles'}), confidence=0.8, lift=3.2176795580110498)]),
#  RelationRecord(items=frozenset({'light bulbs', 'mustard', 'candy'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light bulbs', 'mustard'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'skin care', 'candy', 'liquor'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'skin care', 'liquor'}), items_add=frozenset({'candy'}), confidence=1.0, lift=3.772020725388601)]),
#  RelationRecord(items=frozenset({'misc. beverages', 'nut snack', 'candy'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'nut snack', 'candy'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797), OrderedStatistic(items_base=frozenset({'misc. beverages', 'nut snack'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'photo/film', 'candy', 'roll products '}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'photo/film', 'roll products '}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'make up remover', 'canned beer', 'chocolate'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'make up remover'}), items_add=frozenset({'canned beer', 'chocolate'}), confidence=0.8, lift=3.2355555555555555)]),
#  RelationRecord(items=frozenset({'cream cheese ', 'canned beer', 'rubbing alcohol'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rubbing alcohol'}), items_add=frozenset({'cream cheese ', 'canned beer'}), confidence=0.8, lift=3.4058479532163743)]),
#  RelationRecord(items=frozenset({'canned fish', 'male cosmetics', 'cat food'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned fish', 'male cosmetics'}), items_add=frozenset({'cat food'}), confidence=0.8333333333333333, lift=3.9139784946236555)]),
#  RelationRecord(items=frozenset({'canned fish', 'dishes', 'organic sausage'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned fish', 'organic sausage'}), items_add=frozenset({'dishes'}), confidence=0.8333333333333333, lift=4.892473118279569), OrderedStatistic(items_base=frozenset({'dishes', 'organic sausage'}), items_add=frozenset({'canned fish'}), confidence=1.0, lift=7.207920792079207)]),
#  RelationRecord(items=frozenset({'canned fish', 'soups', 'grapes'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned fish', 'soups'}), items_add=frozenset({'grapes'}), confidence=1.0, lift=4.089887640449438)]),
#  RelationRecord(items=frozenset({'canned fish', 'organic sausage', 'hamburger meat'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'organic sausage', 'hamburger meat'}), items_add=frozenset({'canned fish'}), confidence=0.8, lift=5.766336633663366)]),
#  RelationRecord(items=frozenset({'canned fish', 'hard cheese', 'nuts/prunes'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned fish', 'nuts/prunes'}), items_add=frozenset({'hard cheese'}), confidence=0.8333333333333333, lift=3.279279279279279)]),
#  RelationRecord(items=frozenset({'canned fish', 'liquor (appetizer)', 'specialty cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liquor (appetizer)', 'specialty cheese'}), items_add=frozenset({'canned fish'}), confidence=0.8, lift=5.766336633663366)]),
#  RelationRecord(items=frozenset({'canned fish', 'misc. beverages', 'ready soups'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned fish', 'ready soups'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797)]),
#  RelationRecord(items=frozenset({'canned fish', 'pasta', 'tea'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned fish', 'tea'}), items_add=frozenset({'pasta'}), confidence=0.8, lift=5.153982300884956)]),
#  RelationRecord(items=frozenset({'flour', 'napkins', 'canned fruit'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'napkins', 'canned fruit'}), items_add=frozenset({'flour'}), confidence=0.7142857142857142, lift=3.851851851851851)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'ham', 'canned fruit'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham', 'canned fruit'}), items_add=frozenset({'specialty chocolate'}), confidence=0.8333333333333333, lift=3.0485762144053603)]),
#  RelationRecord(items=frozenset({'processed cheese', 'hard cheese', 'canned fruit'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'processed cheese', 'canned fruit'}), items_add=frozenset({'hard cheese'}), confidence=1.0, lift=3.9351351351351354)]),
#  RelationRecord(items=frozenset({'packaged fruit/vegetables', 'specialty bar', 'canned fruit'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'packaged fruit/vegetables', 'canned fruit'}), items_add=frozenset({'specialty bar'}), confidence=0.8, lift=3.165217391304348)]),
#  RelationRecord(items=frozenset({'canned vegetables', 'salty snack', 'fish'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned vegetables', 'fish'}), items_add=frozenset({'salty snack'}), confidence=1.0, lift=3.1790393013100435)]),
#  RelationRecord(items=frozenset({'canned vegetables', 'grapes', 'skin care'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned vegetables', 'skin care'}), items_add=frozenset({'grapes'}), confidence=1.0, lift=4.089887640449438)]),
#  RelationRecord(items=frozenset({'red/blush wine', 'canned vegetables', 'house keeping products'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned vegetables', 'house keeping products'}), items_add=frozenset({'red/blush wine'}), confidence=0.8333333333333333, lift=4.302600472813238)]),
#  RelationRecord(items=frozenset({'instant coffee', 'canned vegetables', 'hygiene articles'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'instant coffee', 'canned vegetables'}), items_add=frozenset({'hygiene articles'}), confidence=0.75, lift=3.016574585635359)]),
#  RelationRecord(items=frozenset({'canned vegetables', 'popcorn', 'hygiene articles'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned vegetables', 'popcorn'}), items_add=frozenset({'hygiene articles'}), confidence=0.75, lift=3.016574585635359)]),
#  RelationRecord(items=frozenset({'canned vegetables', 'ketchup', 'waffles'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned vegetables', 'ketchup'}), items_add=frozenset({'waffles'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'canned vegetables', 'sauces', 'specialty bar'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned vegetables', 'sauces'}), items_add=frozenset({'specialty bar'}), confidence=1.0, lift=3.956521739130435)]),
#  RelationRecord(items=frozenset({'cereals', 'cat food', 'liquor'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'liquor'}), items_add=frozenset({'cat food'}), confidence=0.8333333333333333, lift=3.9139784946236555)]),
#  RelationRecord(items=frozenset({'hair spray', 'fruit/vegetable juice', 'cat food'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fruit/vegetable juice', 'hair spray'}), items_add=frozenset({'cat food'}), confidence=0.8, lift=3.75741935483871)]),
#  RelationRecord(items=frozenset({'nuts/prunes', 'hard cheese', 'cat food'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'nuts/prunes', 'cat food'}), items_add=frozenset({'hard cheese'}), confidence=0.8333333333333333, lift=3.279279279279279)]),
#  RelationRecord(items=frozenset({'seasonal products', 'cat food', 'house keeping products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'seasonal products', 'house keeping products'}), items_add=frozenset({'cat food'}), confidence=0.8, lift=3.75741935483871)]),
#  RelationRecord(items=frozenset({'ketchup', 'hygiene articles', 'cat food'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ketchup', 'cat food'}), items_add=frozenset({'hygiene articles'}), confidence=0.8, lift=3.2176795580110498)]),
#  RelationRecord(items=frozenset({'male cosmetics', 'hygiene articles', 'cat food'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'male cosmetics', 'hygiene articles'}), items_add=frozenset({'cat food'}), confidence=0.7142857142857142, lift=3.354838709677419)]),
#  RelationRecord(items=frozenset({'light bulbs', 'cat food', 'seasonal products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light bulbs', 'seasonal products'}), items_add=frozenset({'cat food'}), confidence=1.0, lift=4.6967741935483875)]),
#  RelationRecord(items=frozenset({'zwieback', 'liquor (appetizer)', 'cat food'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'zwieback', 'liquor (appetizer)'}), items_add=frozenset({'cat food'}), confidence=1.0, lift=4.6967741935483875)]),
#  RelationRecord(items=frozenset({'liver loaf', 'vinegar', 'cat food'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liver loaf', 'vinegar'}), items_add=frozenset({'cat food'}), confidence=0.8, lift=3.75741935483871)]),
#  RelationRecord(items=frozenset({'male cosmetics', 'napkins', 'cat food'}), support=0.01098901098901099, ordered_statistics=[OrderedStatistic(items_base=frozenset({'male cosmetics', 'napkins'}), items_add=frozenset({'cat food'}), confidence=0.8, lift=3.75741935483871)]),
#  RelationRecord(items=frozenset({'meat', 'spices', 'cat food'}), support=0.009615384615384616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meat', 'spices'}), items_add=frozenset({'cat food'}), confidence=0.7000000000000001, lift=3.2877419354838713)]),
#  RelationRecord(items=frozenset({'nut snack', 'sliced cheese', 'cat food'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'nut snack', 'cat food'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'pot plants', 'cat food', 'tidbits'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pot plants', 'tidbits'}), items_add=frozenset({'cat food'}), confidence=0.8, lift=3.75741935483871)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'cat food', 'tidbits'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sliced cheese', 'tidbits'}), items_add=frozenset({'cat food'}), confidence=0.7142857142857142, lift=3.354838709677419)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'cat food', 'tidbits'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty chocolate', 'tidbits'}), items_add=frozenset({'cat food'}), confidence=1.0, lift=4.6967741935483875)]),
#  RelationRecord(items=frozenset({'cereals', 'chewing gum', 'cling film/bags'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'cling film/bags'}), items_add=frozenset({'chewing gum'}), confidence=0.8, lift=3.5730061349693254)]),
#  RelationRecord(items=frozenset({'cereals', 'flour', 'detergent'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'flour'}), items_add=frozenset({'detergent'}), confidence=0.8333333333333333, lift=5.098039215686274)]),
#  RelationRecord(items=frozenset({'cereals', 'soft cheese', 'detergent'}), support=0.009615384615384616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'soft cheese'}), items_add=frozenset({'detergent'}), confidence=0.875, lift=5.352941176470588)]),
#  RelationRecord(items=frozenset({'mustard', 'cereals', 'hard cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mustard', 'cereals'}), items_add=frozenset({'hard cheese'}), confidence=0.8, lift=3.1481081081081084)]),
#  RelationRecord(items=frozenset({'cereals', 'mayonnaise', 'waffles'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'mayonnaise'}), items_add=frozenset({'waffles'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'mustard', 'cereals', 'sliced cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mustard', 'cereals'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'meat', 'chewing gum', 'cookware'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meat', 'cookware'}), items_add=frozenset({'chewing gum'}), confidence=0.8333333333333333, lift=3.7218813905930466)]),
#  RelationRecord(items=frozenset({'curd', 'flower soil/fertilizer', 'chewing gum'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd', 'flower soil/fertilizer'}), items_add=frozenset({'chewing gum'}), confidence=0.7142857142857142, lift=3.190184049079754)]),
#  RelationRecord(items=frozenset({'chewing gum', 'grapes', 'dental care'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chewing gum', 'dental care'}), items_add=frozenset({'grapes'}), confidence=0.8, lift=3.2719101123595506)]),
#  RelationRecord(items=frozenset({'frankfurter', 'chewing gum', 'liqueur'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frankfurter', 'liqueur'}), items_add=frozenset({'chewing gum'}), confidence=1.0, lift=4.466257668711656)]),
#  RelationRecord(items=frozenset({'chewing gum', 'specialty fat', 'frozen dessert'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty fat', 'frozen dessert'}), items_add=frozenset({'chewing gum'}), confidence=0.8, lift=3.5730061349693254)]),
#  RelationRecord(items=frozenset({'chewing gum', 'pickled vegetables', 'rum'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rum', 'pickled vegetables'}), items_add=frozenset({'chewing gum'}), confidence=0.8, lift=3.5730061349693254)]),
#  RelationRecord(items=frozenset({'specialty bar', 'chewing gum', 'skin care'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chewing gum', 'skin care'}), items_add=frozenset({'specialty bar'}), confidence=0.8333333333333333, lift=3.2971014492753623), OrderedStatistic(items_base=frozenset({'specialty bar', 'skin care'}), items_add=frozenset({'chewing gum'}), confidence=0.7142857142857142, lift=3.190184049079754)]),
# ...
#  RelationRecord(items=frozenset({'misc. beverages', 'ice cream', 'potato products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ice cream', 'potato products'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797)]),
#  RelationRecord(items=frozenset({'ice cream', 'specialty bar', 'potato products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ice cream', 'potato products'}), items_add=frozenset({'specialty bar'}), confidence=0.8, lift=3.165217391304348)]),
#  RelationRecord(items=frozenset({'zwieback', 'ice cream', 'vinegar'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'zwieback', 'vinegar'}), items_add=frozenset({'ice cream'}), confidence=1.0, lift=3.5169082125603865)]),
#  RelationRecord(items=frozenset({'liver loaf', 'instant coffee', 'sliced cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liver loaf', 'instant coffee'}), items_add=frozenset({'sliced cheese'}), confidence=1.0, lift=3.9139784946236564)]),
#  RelationRecord(items=frozenset({'instant coffee', 'oil', 'pot plants'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'instant coffee', 'pot plants'}), items_add=frozenset({'oil'}), confidence=0.8571428571428571, lift=3.1999999999999997)]),
#  RelationRecord(items=frozenset({'instant coffee', 'salty snack', 'vinegar'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'instant coffee', 'vinegar'}), items_add=frozenset({'salty snack'}), confidence=1.0, lift=3.1790393013100435)]),
#  RelationRecord(items=frozenset({'light bulbs', 'soft cheese', 'mustard'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light bulbs', 'mustard'}), items_add=frozenset({'soft cheese'}), confidence=1.0, lift=5.126760563380282)]),
#  RelationRecord(items=frozenset({'light bulbs', 'sugar', 'roll products '}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light bulbs', 'roll products '}), items_add=frozenset({'sugar'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'whipped/sour cream', 'pickled vegetables', 'liqueur'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'liqueur'}), items_add=frozenset({'pickled vegetables'}), confidence=0.8333333333333333, lift=5.013774104683195)]),
#  RelationRecord(items=frozenset({'processed cheese', 'liqueur', 'waffles'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'processed cheese', 'liqueur'}), items_add=frozenset({'waffles'}), confidence=1.0, lift=3.3548387096774195), OrderedStatistic(items_base=frozenset({'liqueur', 'waffles'}), items_add=frozenset({'processed cheese'}), confidence=0.8, lift=4.189928057553957)]),
#  RelationRecord(items=frozenset({'meat', 'male cosmetics', 'liquor (appetizer)'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'male cosmetics', 'liquor (appetizer)'}), items_add=frozenset({'meat'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'liver loaf', 'vinegar', 'processed cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liver loaf', 'vinegar'}), items_add=frozenset({'processed cheese'}), confidence=0.8, lift=4.189928057553957)]),
#  RelationRecord(items=frozenset({'sugar', 'organic products', 'long life bakery product'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'organic products', 'long life bakery product'}), items_add=frozenset({'sugar'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'sweet spreads', 'rice', 'long life bakery product'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sweet spreads', 'rice'}), items_add=frozenset({'long life bakery product'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'long life bakery product', 'tidbits', 'seasonal products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tidbits', 'seasonal products'}), items_add=frozenset({'long life bakery product'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'long life bakery product', 'tidbits'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty chocolate', 'tidbits'}), items_add=frozenset({'long life bakery product'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'zwieback', 'vinegar', 'long life bakery product'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'zwieback', 'vinegar'}), items_add=frozenset({'long life bakery product'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'make up remover', 'margarine', 'pip fruit'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'make up remover'}), items_add=frozenset({'margarine', 'pip fruit'}), confidence=1.0, lift=3.294117647058824)]),
#  RelationRecord(items=frozenset({'male cosmetics', 'mayonnaise', 'seasonal products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'male cosmetics', 'mayonnaise'}), items_add=frozenset({'seasonal products'}), confidence=0.8, lift=5.709803921568628)]),
#  RelationRecord(items=frozenset({'male cosmetics', 'pot plants', 'waffles'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'male cosmetics', 'pot plants'}), items_add=frozenset({'waffles'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'margarine', 'sliced cheese', 'pudding powder'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'margarine', 'pudding powder'}), items_add=frozenset({'sliced cheese'}), confidence=0.8571428571428571, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'meat spreads', 'mayonnaise', 'sliced cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meat spreads', 'mayonnaise'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'meat spreads', 'sliced cheese', 'seasonal products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meat spreads', 'seasonal products'}), items_add=frozenset({'sliced cheese'}), confidence=1.0, lift=3.9139784946236564)]),
#  RelationRecord(items=frozenset({'misc. beverages', 'onions', 'ready soups'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'onions', 'ready soups'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797)]),
#  RelationRecord(items=frozenset({'misc. beverages', 'whisky', 'pastry'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whisky', 'pastry'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797)]),
#  RelationRecord(items=frozenset({'misc. beverages', 'sparkling wine', 'pot plants'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sparkling wine', 'pot plants'}), items_add=frozenset({'misc. beverages'}), confidence=1.0, lift=3.8930481283422465)]),
#  RelationRecord(items=frozenset({'misc. beverages', 'specialty fat', 'roll products '}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty fat', 'roll products '}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797)]),
#  RelationRecord(items=frozenset({'misc. beverages', 'salad dressing', 'whipped/sour cream'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'salad dressing'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797)]),
#  RelationRecord(items=frozenset({'misc. beverages', 'vinegar', 'zwieback'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'zwieback', 'vinegar'}), items_add=frozenset({'misc. beverages'}), confidence=1.0, lift=3.8930481283422465)]),
#  RelationRecord(items=frozenset({'oil', 'salad dressing', 'other vegetables'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing'}), items_add=frozenset({'oil', 'other vegetables'}), confidence=0.8333333333333333, lift=3.37037037037037), OrderedStatistic(items_base=frozenset({'other vegetables', 'salad dressing'}), items_add=frozenset({'oil'}), confidence=0.8333333333333333, lift=3.1111111111111107)]),
#  RelationRecord(items=frozenset({'oil', 'salad dressing', 'rolls/buns'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing'}), items_add=frozenset({'oil', 'rolls/buns'}), confidence=0.8333333333333333, lift=3.4082397003745317), OrderedStatistic(items_base=frozenset({'salad dressing', 'rolls/buns'}), items_add=frozenset({'oil'}), confidence=0.8333333333333333, lift=3.1111111111111107)]),
#  RelationRecord(items=frozenset({'root vegetables', 'oil', 'salad dressing'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing'}), items_add=frozenset({'root vegetables', 'oil'}), confidence=0.8333333333333333, lift=3.991228070175438), OrderedStatistic(items_base=frozenset({'root vegetables', 'salad dressing'}), items_add=frozenset({'oil'}), confidence=0.8333333333333333, lift=3.1111111111111107)]),
#  RelationRecord(items=frozenset({'specialty bar', 'oil', 'rum'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'oil', 'rum'}), items_add=frozenset({'specialty bar'}), confidence=1.0, lift=3.956521739130435)]),
#  RelationRecord(items=frozenset({'oil', 'salad dressing', 'whole milk'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing'}), items_add=frozenset({'oil', 'whole milk'}), confidence=0.8333333333333333, lift=3.2269503546099285), OrderedStatistic(items_base=frozenset({'salad dressing', 'whole milk'}), items_add=frozenset({'oil'}), confidence=0.8333333333333333, lift=3.1111111111111107)]),
#  RelationRecord(items=frozenset({'white wine', 'onions', 'spices'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'onions', 'spices'}), items_add=frozenset({'white wine'}), confidence=0.7142857142857142, lift=3.3121019108280247)]),
#  RelationRecord(items=frozenset({'packaged fruit/vegetables', 'soft cheese', 'soap'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'packaged fruit/vegetables', 'soap'}), items_add=frozenset({'soft cheese'}), confidence=0.8, lift=4.101408450704225), OrderedStatistic(items_base=frozenset({'soft cheese', 'soap'}), items_add=frozenset({'packaged fruit/vegetables'}), confidence=0.8, lift=4.6592)]),
#  RelationRecord(items=frozenset({'popcorn', 'soft cheese', 'pot plants'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'popcorn', 'pot plants'}), items_add=frozenset({'soft cheese'}), confidence=0.7142857142857142, lift=3.661971830985915)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'pot plants', 'tidbits'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pot plants', 'tidbits'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'processed cheese', 'snack products', 'roll products '}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'processed cheese', 'snack products'}), items_add=frozenset({'roll products '}), confidence=0.7142857142857142, lift=6.753246753246753), OrderedStatistic(items_base=frozenset({'snack products', 'roll products '}), items_add=frozenset({'processed cheese'}), confidence=0.7142857142857142, lift=3.741007194244604)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'sliced cheese', 'pudding powder'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty chocolate', 'pudding powder'}), items_add=frozenset({'sliced cheese'}), confidence=1.0, lift=3.9139784946236564)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'white bread', 'pudding powder'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'white bread', 'pudding powder'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'vinegar', 'red/blush wine', 'seasonal products'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'vinegar', 'seasonal products'}), items_add=frozenset({'red/blush wine'}), confidence=0.7142857142857142, lift=3.687943262411347)]),
#  RelationRecord(items=frozenset({'red/blush wine', 'specialty cheese', 'tidbits'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty cheese', 'tidbits'}), items_add=frozenset({'red/blush wine'}), confidence=1.0, lift=5.163120567375886)]),
#  RelationRecord(items=frozenset({'specialty bar', 'rum', 'salty snack'}), support=0.009615384615384616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rum', 'salty snack'}), items_add=frozenset({'specialty bar'}), confidence=0.875, lift=3.4619565217391304)]),
#  RelationRecord(items=frozenset({'vinegar', 'softener', 'salty snack'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'vinegar', 'softener'}), items_add=frozenset({'salty snack'}), confidence=1.0, lift=3.1790393013100435)]),
#  RelationRecord(items=frozenset({'zwieback', 'sliced cheese', 'seasonal products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'zwieback', 'seasonal products'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'syrup', 'sliced cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty chocolate', 'syrup'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'sugar', 'soft cheese', 'specialty fat'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soft cheese', 'specialty fat'}), items_add=frozenset({'sugar'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'white wine', 'sparkling wine'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty chocolate', 'sparkling wine'}), items_add=frozenset({'white wine'}), confidence=0.8571428571428571, lift=3.97452229299363)]),
#  RelationRecord(items=frozenset({'spread cheese', 'specialty bar', 'spices'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spread cheese', 'spices'}), items_add=frozenset({'specialty bar'}), confidence=0.8, lift=3.165217391304348)]),
#  RelationRecord(items=frozenset({'zwieback', 'waffles', 'tidbits'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'zwieback', 'tidbits'}), items_add=frozenset({'waffles'}), confidence=1.0, lift=3.3548387096774195)])]

# %%
len(results)
# Out:
# 379

# %%
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
resultsinDataFrame.head()
# Out:
#           Left Hand Side      Right Hand Side   Support  Confidence      Lift
# 0         salad dressing                  oil  0.006868    0.833333  3.111111
# 1  Instant food products  semi-finished bread  0.005495    0.800000  4.585827
# 2                mustard                 salt  0.005495    0.800000  7.372152
# 3          spread cheese   pickled vegetables  0.005495    0.800000  4.813223
# 4          spread cheese        sliced cheese  0.005495    0.800000  3.131183

# %%
resultsinDataFrame.nlargest(n = 10, columns = 'Lift')
# Out:
#          Left Hand Side         Right Hand Side   Support  Confidence  \
# 97    finished products  frozen potato products  0.005495    0.800000
# 36          light bulbs         cling film/bags  0.005495    0.800000
# 105             candles        specialty cheese  0.005495    0.800000
# 211  pickled vegetables           spread cheese  0.005495    1.000000
# 2               mustard                    salt  0.005495    0.800000
# 366    processed cheese          roll products   0.006868    0.714286
# 35            chocolate           baking powder  0.005495    1.000000
# 37                 curd           baking powder  0.005495    1.000000
# 40                herbs           baking powder  0.005495    1.000000
# 191        cocoa drinks              pot plants  0.005495    1.000000
#
#          Lift
# 97   8.692537
# 36   8.320000
# 105  8.320000
# 211  7.663158
# 2    7.372152
# 366  6.753247
# 35   6.618182
# 37   6.618182
# 40   6.618182
# 191  6.385965
